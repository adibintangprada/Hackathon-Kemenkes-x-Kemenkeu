# %%
import pandas as pd

# %%
apbd_2021 = pd.read_csv("A2021_dataset contoh.csv", sep=";")
# Out:
# C:\Users\Bintang\AppData\Local\Temp\ipykernel_18504\1435835615.py:1: DtypeWarning: Columns (9,14,16,18,22,24,26,28,30,32,34,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   apbd_2021 = pd.read_csv("A2021_dataset contoh.csv", sep=";")

# %%
apbd2021_fungsifix = apbd_2021.copy()

# %% [markdown]
# # Selecting only Provinsi

# %%
apbd2021_fungsifix
# Out:
#          apbdindex  kodesatker  kodepemda                  namapemda  \
# 0            15010      963311       1.22            Kab. Pidie Jaya
# 1            15010      963311       1.22            Kab. Pidie Jaya
# 2            15010      963311       1.22            Kab. Pidie Jaya
# 3            15010      963311       1.22            Kab. Pidie Jaya
# 4            15010      963311       1.22            Kab. Pidie Jaya
# ...            ...         ...        ...                        ...
# 4171276      15450      999001      34.00  Provinsi Kalimantan Utara
# 4171277      15450      999001      34.00  Provinsi Kalimantan Utara
# 4171278      15450      999001      34.00  Provinsi Kalimantan Utara
# 4171279      15450      999001      34.00  Provinsi Kalimantan Utara
# 4171280      15450      999001      34.00  Provinsi Kalimantan Utara
#
#          tahunanggaran        tglpengiriman  kodedata  statusdata  jeniscoa  \
# ...

# %%
apbd2021_fungsifix = apbd2021_fungsifix[apbd2021_fungsifix.namapemda.str.match("Provinsi.*")]

# %%
apbd2021_fungsifix
# Out:
#          apbdindex  kodesatker  kodepemda                  namapemda  \
# 80           15077      990015        1.0              Provinsi Aceh
# 93           15077      990015        1.0              Provinsi Aceh
# 99           15077      990015        1.0              Provinsi Aceh
# 110          15077      990015        1.0              Provinsi Aceh
# 111          15077      990015        1.0              Provinsi Aceh
# ...            ...         ...        ...                        ...
# 4171276      15450      999001       34.0  Provinsi Kalimantan Utara
# 4171277      15450      999001       34.0  Provinsi Kalimantan Utara
# 4171278      15450      999001       34.0  Provinsi Kalimantan Utara
# 4171279      15450      999001       34.0  Provinsi Kalimantan Utara
# 4171280      15450      999001       34.0  Provinsi Kalimantan Utara
#
#          tahunanggaran        tglpengiriman  kodedata  statusdata  jeniscoa  \
# ...

# %%
apbd2021_fungsifix.columns
# Out:
# Index(['apbdindex', 'kodesatker', 'kodepemda', 'namapemda', 'tahunanggaran',
#        'tglpengiriman', 'kodedata', 'statusdata', 'jeniscoa', 'nomorperda',
#        'tanggalperda', 'namaaplikasi', 'pengembangaplikasi', 'kegiatanindex',
#        'kodeurusanprogram', 'namaurusanprogram', 'kodeurusanpelaksana',
#        'namaurusanpelaksana', 'kodeskpd', 'namaskpd', 'kodeprogram',
#        'namaprogram', 'kodekegiatan', 'namakegiatan', 'kodefungsi',
#        'namafungsi', 'kodeakunutama', 'namaakunutama', 'kodeakunkelompok',
#        'namaakunkelompok', 'kodeakunjenis', 'namaakunjenis', 'kodeakunobjek',
#        'namaakunobjek', 'kodeakunrincian', 'namaakunrincian', 'kodeakunsub',
#        'namaakunsub', 'nilaianggaran', 'standarfungsimapped', 'standarjenis',
#        'standarobjek', 'md5', 'prov'],
#       dtype='object')

# %%
apbd2021_fungsifix["namapemda"].nunique()
# Out:
# 34

# %%
apbd2021_fungsifix["standarfungsimapped"].nunique()
# Out:
# 10

# %%
apbd2021_fungsifix["standarfungsimapped"].unique()
# Out:
# array(['10. Pendidikan', '1. Pelayanan Umum',
#        '3. Ketertiban dan Keamanan', '11. Perlindungan Sosial',
#        '4. Ekonomi', '8. Pariwisata dan Budaya', '7. Kesehatan',
#        '6. Perumahan dan Fasilitas Umum', '5. Lingkungan Hidup',
#        'unmapped'], dtype=object)

# %%
apbd2021_fungsifix["standarfungsimapped"].replace({"10. Pendidikan":"Pendidikan",
                                                   "1. Pelayanan Umum":"Pelayanan Umum",
                                                   "3. Ketertiban dan Keamanan":"Ketertiban dan Keamanan",
                                                   "11. Perlindungan Sosial":"Perlindungan Sosial",
                                                   "4. Ekonomi":"Ekonomi",
                                                   "8. Pariwisata dan Budaya":"Pariwisata",
                                                   "7. Kesehatan":"Kesehatan",
                                                   "6. Perumahan dan Fasilitas Umum":"Perumahan dan Fasilitas Umum",
                                                   "5. Lingkungan Hidup":"Lingkungan Hidup",
                                                   "unmapped":"Lainnya"}, inplace=True)
# Out:
# C:\Users\Bintang\AppData\Local\Temp\ipykernel_18504\635402669.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apbd2021_fungsifix["standarfungsimapped"].replace({"10. Pendidikan":"Pendidikan",

# %%
apbd2021_fungsifix["standarfungsimapped"].unique()
# Out:
# array(['Pendidikan', 'Pelayanan Umum', 'Ketertiban dan Keamanan',
#        'Perlindungan Sosial', 'Ekonomi', 'Pariwisata', 'Kesehatan',
#        'Perumahan dan Fasilitas Umum', 'Lingkungan Hidup', 'Lainnya'],
#       dtype=object)

# %%
apbd2021_fungsifix["namaurusanprogram"].nunique()
# Out:
# 194

# %%
apbd2021_fungsifix["namaurusanprogram"].unique()
# Out:
# array(['URUSAN PEMERINTAHAN BIDANG PENDIDIKAN', 'SEKRETARIAT DAERAH',
#        'SEKRETARIAT DPRD', 'PERENCANAAN', 'KEPEGAWAIAN',
#        'PENDIDIKAN DAN PELATIHAN', 'KEKHUSUSAN ACEH',
#        'KETENTERAMAN KETERTIBAN UMUM DAN PERLINDUNGAN MASYARAKAT',
#        'URUSAN PEMERINTAHAN BIDANG SOSIAL',
#        'URUSAN PEMERINTAHAN BIDANG LINGKUNGAN HIDUP',
#        'URUSAN PEMERINTAHAN BIDANG ADMINISTRASI KEPENDUDUKAN DAN PENCATATAN SIPIL',
#        'URUSAN PEMERINTAHAN BIDANG PENANAMAN MODAL',
#        'URUSAN PEMERINTAHAN BIDANG KEBUDAYAAN',
#        'URUSAN PEMERINTAHAN BIDANG PERPUSTAKAAN',
#        'URUSAN PEMERINTAHAN BIDANG KELAUTAN DAN PERIKANAN',
#        'URUSAN PEMERINTAHAN BIDANG PARIWISATA',
#        'URUSAN PEMERINTAHAN BIDANG PERTANIAN',
#        'ENERGI DAN SUMBER DAYA MINERAL', 'PERDAGANGAN', 'KEUANGAN',
#        'KESATUAN BANGSA DAN POLITIK',
#        'URUSAN PEMERINTAHAN BIDANG KESEHATAN',
# ...

# %%
apbd2021_fungsifix["namaurusanprogram"].replace({"Non Urusan":"NON URUSAN"}, inplace=True)
# Out:
# C:\Users\Bintang\AppData\Local\Temp\ipykernel_18504\3641741580.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apbd2021_fungsifix["namaurusanprogram"].replace({"Non Urusan":"NON URUSAN"}, inplace=True)

# %%
apbd2021_fungsifix["namaurusanprogram"] = apbd2021_fungsifix["namaurusanprogram"].str.strip()
# Out:
# C:\Users\Bintang\AppData\Local\Temp\ipykernel_18504\1654822997.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apbd2021_fungsifix["namaurusanprogram"] = apbd2021_fungsifix["namaurusanprogram"].str.strip()

# %%
apbd2021_fungsifix["namaurusanprogram"].nunique()
# Out:
# 193

# %%
apbd2021_fungsifix["namaprogram"].nunique()
# Out:
# 273

# %%
apbd2021_fungsifix["namaprogram"].unique()
# Out:
# array(['PROGRAM PENGELOLAAN PENDIDIKAN',
#        'PROGRAM PEMERINTAHAN DAN OTONOMI DAERAH',
#        'PROGRAM PENUNJANG URUSAN PEMERINTAHAN DAERAH PROVINSI',
#        'PROGRAM DUKUNGAN PELAKSANAAN TUGAS DAN FUNGSI DPRD',
#        'PROGRAM PERENCANAAN PENGENDALIAN DAN EVALUASI PEMBANGUNAN DAERAH',
#        'PROGRAM KEPEGAWAIAN DAERAH',
#        'PROGRAM PERLINDUNGAN DAN JAMINAN SOSIAL',
#        'PROGRAM PENGELOLAAN KEANEKARAGAMAN HAYATI KEHATI',
#        'PROGRAM PENGENDALIAN PELAKSANAAN PENANAMAN MODAL',
#        'PROGRAM MAJELIS ADAT ACEH MAA',
#        'PROGRAM PENGAWASAN SUMBER DAYA KELAUTAN DAN PERIKANAN',
#        'PROGRAM PEMASARAN PARIWISATA',
#        'PROGRAM PENGELOLAAN ENERGI TERBARUKAN',
#        'PROGRAM PERIZINAN DAN PENDAFTARAN PERUSAHAAN',
#        'PROGRAM SYARIAT ISLAM ACEH', 'Non Program',
#        'PROGRAM PEMBINAAN PERPUSTAKAAN',
#        'PROGRAM KOORDINASI DAN SINKRONISASI PERENCANAAN PEMBANGUNAN DAERAH',
# ...

# %%
apbd2021_fungsifix["namaprogram"].replace({"Non Program":"NON PROGRAM",
                                           "Non-Program":"NON PROGRAM"}, inplace=True)
# Out:
# C:\Users\Bintang\AppData\Local\Temp\ipykernel_18504\906249197.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apbd2021_fungsifix["namaprogram"].replace({"Non Program":"NON PROGRAM",

# %%
apbd2021_fungsifix["namaprogram"] = apbd2021_fungsifix["namaprogram"].str.strip()
# Out:
# C:\Users\Bintang\AppData\Local\Temp\ipykernel_18504\3468296878.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apbd2021_fungsifix["namaprogram"] = apbd2021_fungsifix["namaprogram"].str.strip()

# %%
apbd2021_fungsifix["namaprogram"].nunique()
# Out:
# 271

# %%
apbd2021_fungsifix["namaprogram"] = apbd2021_fungsifix["namaprogram"].str.upper()
# Out:
# C:\Users\Bintang\AppData\Local\Temp\ipykernel_18504\3299439987.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apbd2021_fungsifix["namaprogram"] = apbd2021_fungsifix["namaprogram"].str.upper()

# %%
apbd2021_fungsifix["namaprogram"].nunique()
# Out:
# 271

# %%
apbd2021_fungsifix["namakegiatan"].nunique()
# Out:
# 9649

# %%
apbd2021_fungsifix["namakegiatan"].unique()
# Out:
# array(['Pengelolaan Pendidikan Sekolah Menengah Atas',
#        'Pelaksanaan Otonomi Daerah',
#        'Administrasi Keuangan Perangkat Daerah', ...,
#        'Pendataan Penyediaan dan Rehabilitasi Rumah Korban Bencana atau Relokasi Program Provinsi|Pendataan Rumah Sewa Milik Masyarakat, Rumah Susun dan Rumah Khusus',
#        'Pengembangan dan Pengelolaan Sistem Irigasi Primer dan Sekunder pada Daerah Irigasi yang Luasnya 1000 Ha - 3000 Ha dan Daerah Irigasi Lintas Daerah Kabupaten/Kota|Pembangunan Jaringan Irigasi Rawa',
#        'Penguatan dan Pengembangan Lembaga Penyedia Layanan bagi Anak yang Memerlukan Perlindungan Khusus Tingkat Daerah Provinsi dan Lintas Daerah Kabupaten/Kota|Koordinasi dan Sinkronisasi Penguatan Jejaring antar Lembaga Penyedia Layanan Anak yang Memerlukan Perlindungan Khusus Kewenangan Provinsi'],
#       dtype=object)

# %%
apbd2021_fungsifix["namakegiatan"] = apbd2021_fungsifix["namakegiatan"].str.strip()
# Out:
# C:\Users\Bintang\AppData\Local\Temp\ipykernel_18504\4113106782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apbd2021_fungsifix["namakegiatan"] = apbd2021_fungsifix["namakegiatan"].str.strip()

# %%
apbd2021_fungsifix["namakegiatan"] = apbd2021_fungsifix["namakegiatan"].str.upper()
# Out:
# C:\Users\Bintang\AppData\Local\Temp\ipykernel_18504\2277910529.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apbd2021_fungsifix["namakegiatan"] = apbd2021_fungsifix["namakegiatan"].str.upper()

# %%
apbd2021_fungsifix["namakegiatan"].nunique()
# Out:
# 9503

# %%
apbd2021_fungsifix["standarfungsimapped"].unique()
# Out:
# array(['Pendidikan', 'Pelayanan Umum', 'Ketertiban dan Keamanan',
#        'Perlindungan Sosial', 'Ekonomi', 'Pariwisata', 'Kesehatan',
#        'Perumahan dan Fasilitas Umum', 'Lingkungan Hidup', 'Lainnya'],
#       dtype=object)

# %%
apbd2021_pendidikan = apbd2021_fungsifix[apbd2021_fungsifix["standarfungsimapped"] == "Pendidikan"]

# %%
apbd2021_pendidikan.to_csv("APBD_2021_Pendidikan.csv", index=False, sep=";")

# %%
pelumum = apbd2021_fungsifix[apbd2021_fungsifix["standarfungsimapped"] == "Pelayanan Umum"]

# %%
pelumum.head(1)
# Out:
#     apbdindex  kodesatker  kodepemda      namapemda  tahunanggaran  \
# 93      15077      990015        1.0  Provinsi Aceh           2021
#
#           tglpengiriman  kodedata  statusdata  jeniscoa    nomorperda  ...  \
# 93  2021-01-26 11:46:57         0           4         3  1 Tahun 2021  ...
#
#    kodeakunrincian      namaakunrincian kodeakunsub  \
# 93               1  Belanja Jasa Kantor          28
#
#                            namaakunsub nilaianggaran standarfungsimapped  \
# 93  Belanja Jasa Tenaga Pelayanan Umum    33600000.0      Pelayanan Umum
#
#                 standarjenis                standarobjek  \
# 93  522. Belanja Barang Jasa  52203. Belanja Jasa Kantor
#
#                                  md5 prov
# 93  7c64912c2414ed73d42b20a5d50eeaf3    1
#
# [1 rows x 44 columns]

# %%
pelumum.to_csv("APBD_2021_Pelayanan_Umum.csv", index=False, sep=";")

# %%
ketertiban = apbd2021_fungsifix[apbd2021_fungsifix["standarfungsimapped"] == "Ketertiban dan Keamanan"]

# %%
ketertiban.head(1)
# Out:
#      apbdindex  kodesatker  kodepemda      namapemda  tahunanggaran  \
# 131      15077      990015        1.0  Provinsi Aceh           2021
#
#            tglpengiriman  kodedata  statusdata  jeniscoa    nomorperda  ...  \
# 131  2021-01-26 11:46:57         0           4         3  1 Tahun 2021  ...
#
#     kodeakunrincian      namaakunrincian kodeakunsub  \
# 131               1  Belanja Jasa Kantor          33
#
#                    namaakunsub nilaianggaran      standarfungsimapped  \
# 131  Belanja Jasa Tenaga Supir    39600000.0  Ketertiban dan Keamanan
#
#                  standarjenis                standarobjek  \
# 131  522. Belanja Barang Jasa  52203. Belanja Jasa Kantor
#
#                                   md5 prov
# 131  f77a3069ff1dbc1798a0913b6399a7c2    1
#
# [1 rows x 44 columns]

# %%
ketertiban.to_csv("APBD_2021_Ketertiban_dan_Keamanan.csv", index=False, sep=";")

# %%
sosial = apbd2021_fungsifix[apbd2021_fungsifix["standarfungsimapped"] == "Perlindungan Sosial"]

# %%
sosial.head(1)
# Out:
#      apbdindex  kodesatker  kodepemda      namapemda  tahunanggaran  \
# 132      15077      990015        1.0  Provinsi Aceh           2021
#
#            tglpengiriman  kodedata  statusdata  jeniscoa    nomorperda  ...  \
# 132  2021-01-26 11:46:57         0           4         3  1 Tahun 2021  ...
#
#     kodeakunrincian      namaakunrincian kodeakunsub  \
# 132               1  Belanja Jasa Kantor          63
#
#                                           namaakunsub nilaianggaran  \
# 132  Belanja Kawat Faksimili Internet TV Berlangganan    26400000.0
#
#      standarfungsimapped              standarjenis  \
# 132  Perlindungan Sosial  522. Belanja Barang Jasa
#
#                    standarobjek                               md5 prov
# 132  52203. Belanja Jasa Kantor  1c58a1b461193b8ee4515ce93d79cec2    1
#
# [1 rows x 44 columns]

# %%
sosial.to_csv("APBD_2021_Perlindungan_Sosial.csv", index=False, sep=";")

# %%
ekonomi = apbd2021_fungsifix[apbd2021_fungsifix["standarfungsimapped"] == "Ekonomi"]

# %%
ekonomi.head(1)
# Out:
#      apbdindex  kodesatker  kodepemda      namapemda  tahunanggaran  \
# 133      15077      990015        1.0  Provinsi Aceh           2021
#
#            tglpengiriman  kodedata  statusdata  jeniscoa    nomorperda  ...  \
# 133  2021-01-26 11:46:57         0           4         3  1 Tahun 2021  ...
#
#     kodeakunrincian             namaakunrincian kodeakunsub  \
# 133               1  Belanja Barang Pakai Habis          24
#
#                                            namaakunsub nilaianggaran  \
# 133  Belanja Alat Bahan untuk Kegiatan Kantor-Alat ...     4154032.0
#
#     standarfungsimapped              standarjenis standarobjek  \
# 133             Ekonomi  522. Belanja Barang Jasa     unmapped
#
#                                   md5 prov
# 133  09fa16b7265b460ddeccb6f160bd7772    1
#
# [1 rows x 44 columns]

# %%
ekonomi.to_csv("APBD_2021_Ekonomi.csv", index=False, sep=";")

# %%
pariwisata = apbd2021_fungsifix[apbd2021_fungsifix["standarfungsimapped"] == "Pariwisata"]

# %%
pariwisata.head(1)
# Out:
#      apbdindex  kodesatker  kodepemda      namapemda  tahunanggaran  \
# 136      15077      990015        1.0  Provinsi Aceh           2021
#
#            tglpengiriman  kodedata  statusdata  jeniscoa    nomorperda  ...  \
# 136  2021-01-26 11:46:57         0           4         3  1 Tahun 2021  ...
#
#     kodeakunrincian             namaakunrincian kodeakunsub  \
# 136               1  Belanja Barang Pakai Habis          26
#
#                                            namaakunsub nilaianggaran  \
# 136  Belanja Alat Bahan untuk Kegiatan Kantor- Baha...     3525150.0
#
#     standarfungsimapped              standarjenis standarobjek  \
# 136          Pariwisata  522. Belanja Barang Jasa     unmapped
#
#                                   md5 prov
# 136  e196121b97dc6e7f7762dede2ad00165    1
#
# [1 rows x 44 columns]

# %%
pariwisata.to_csv("APBD_2021_Pariwisata.csv", index=False, sep=";")

# %%
kesehatan = apbd2021_fungsifix[apbd2021_fungsifix["standarfungsimapped"] == "Kesehatan"]

# %%
kesehatan.head(1)
# Out:
#      apbdindex  kodesatker  kodepemda      namapemda  tahunanggaran  \
# 680      15077      990015        1.0  Provinsi Aceh           2021
#
#            tglpengiriman  kodedata  statusdata  jeniscoa    nomorperda  ...  \
# 680  2021-01-26 11:46:57         0           4         3  1 Tahun 2021  ...
#
#     kodeakunrincian      namaakunrincian kodeakunsub  \
# 680               1  Belanja Jasa Kantor           4
#
#                                            namaakunsub nilaianggaran  \
# 680  Honorarium Tim Pelaksana Kegiatan dan Sekretar...   250400000.0
#
#     standarfungsimapped              standarjenis                standarobjek  \
# 680           Kesehatan  522. Belanja Barang Jasa  52203. Belanja Jasa Kantor
#
#                                   md5 prov
# 680  6e6aab6885b15c016a9b6c7475d3d8cf    1
#
# [1 rows x 44 columns]

# %%
kesehatan.to_csv("APBD_2021_Kesehatan.csv", index=False, sep=";")

# %%
perumahan = apbd2021_fungsifix[apbd2021_fungsifix["standarfungsimapped"] == "Perumahan dan Fasilitas Umum"]

# %%
perumahan.head(1)
# Out:
#       apbdindex  kodesatker  kodepemda      namapemda  tahunanggaran  \
# 1307      15077      990015        1.0  Provinsi Aceh           2021
#
#             tglpengiriman  kodedata  statusdata  jeniscoa    nomorperda  ...  \
# 1307  2021-01-26 11:46:57         0           4         3  1 Tahun 2021  ...
#
#      kodeakunrincian      namaakunrincian kodeakunsub  \
# 1307               1  Belanja Jasa Kantor           4
#
#                                             namaakunsub nilaianggaran  \
# 1307  Honorarium Tim Pelaksana Kegiatan dan Sekretar...    19200000.0
#
#                standarfungsimapped              standarjenis  \
# 1307  Perumahan dan Fasilitas Umum  522. Belanja Barang Jasa
#
#                     standarobjek                               md5 prov
# 1307  52203. Belanja Jasa Kantor  01cde63c7f0377af5c1bc403ffa3bdfa    1
#
# [1 rows x 44 columns]

# %%
perumahan.to_csv("APBD_2021_Perumahan_dan_Fasilitas_Umum.csv", index=False, sep=";")

# %%
lingkungan = apbd2021_fungsifix[apbd2021_fungsifix["standarfungsimapped"] == "Lingkungan Hidup"]

# %%
lingkungan.head(1)
# Out:
#       apbdindex  kodesatker  kodepemda      namapemda  tahunanggaran  \
# 1910      15077      990015        1.0  Provinsi Aceh           2021
#
#             tglpengiriman  kodedata  statusdata  jeniscoa    nomorperda  ...  \
# 1910  2021-01-26 11:46:57         0           4         3  1 Tahun 2021  ...
#
#      kodeakunrincian      namaakunrincian kodeakunsub  \
# 1910               1  Belanja Jasa Kantor          26
#
#                            namaakunsub nilaianggaran standarfungsimapped  \
# 1910  Belanja Jasa Tenaga Administrasi   470400000.0    Lingkungan Hidup
#
#                   standarjenis                standarobjek  \
# 1910  522. Belanja Barang Jasa  52203. Belanja Jasa Kantor
#
#                                    md5 prov
# 1910  2be8de59db648617ebe1d41607bfc55f    1
#
# [1 rows x 44 columns]

# %%
lingkungan.to_csv("APBD_2021_Lingkungan_Hidup.csv", index=False, sep=";")

# %%
lainnya = apbd2021_fungsifix[apbd2021_fungsifix["standarfungsimapped"] == "Lainnya"]

# %%
lainnya.head(1)
# Out:
#          apbdindex  kodesatker  kodepemda                  namapemda  \
# 2319235      15014      991947       14.0  Provinsi Kalimantan Barat
#
#          tahunanggaran        tglpengiriman  kodedata  statusdata  jeniscoa  \
# 2319235           2021  2021-01-26 21:21:34         0           4         3
#
#         nomorperda  ... kodeakunrincian      namaakunrincian kodeakunsub  \
# 2319235         00  ...             01   Belanja Jasa Kantor        0062
#
#                                           namaakunsub nilaianggaran  \
# 2319235  Belanja Langganan Jurnal Surat Kabar Majalah     8040000.0
#
#         standarfungsimapped              standarjenis  \
# 2319235             Lainnya  522. Belanja Barang Jasa
#
#                        standarobjek                               md5 prov
# 2319235  52203. Belanja Jasa Kantor  74b49cea4fe1cac4ccbcb59a8d981242   14
#
# [1 rows x 44 columns]

# %%
lainnya.to_csv("APBD_2021_Lainnya.csv", index=False, sep=";")
